# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline

# %%
df = pd.read_csv('./data/Sample Media Spend Data.csv')

df
# Out:
#      Division Calendar_Week  Paid_Views  Organic_Views  Google_Impressions  \
# 0           A      1/6/2018         392            422                 408
# 1           A     1/13/2018         787            904                 110
# 2           A     1/20/2018          81            970                 742
# 3           A     1/27/2018          25            575                  65
# 4           A      2/3/2018         565            284                 295
# ...       ...           ...         ...            ...                 ...
# 3046        Z      2/1/2020       29239          25311              622406
# 3047        Z      2/8/2020       26230          28031              624409
# 3048        Z     2/15/2020       24749          31281              439362
# 3049        Z     2/22/2020       20713          30356              464178
# 3050        Z     2/29/2020       15990          26993              449032
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3051 entries, 0 to 3050
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Division               3051 non-null   object
#  1   Calendar_Week          3051 non-null   object
#  2   Paid_Views             3051 non-null   int64
#  3   Organic_Views          3051 non-null   int64
#  4   Google_Impressions     3051 non-null   int64
#  5   Email_Impressions      3051 non-null   float64
#  6   Facebook_Impressions   3051 non-null   int64
#  7   Affiliate_Impressions  3051 non-null   int64
#  8   Overall_Views          3051 non-null   int64
#  9   Sales                  3051 non-null   int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 238.5+ KB

# %%
df['Calendar_Week'] = pd.to_datetime(df['Calendar_Week'])

# %%
pd.DataFrame(
    [df.isna().sum(), df.nunique()]
).T.rename(columns={0:'missing value', 1:"unique_values"})
# Out:
#                        missing value  unique_values
# Division                           0             26
# Calendar_Week                      0            113
# Paid_Views                         0           2345
# Organic_Views                      0           2553
# Google_Impressions                 0           2913
# Email_Impressions                  0           3051
# Facebook_Impressions               0           3036
# Affiliate_Impressions              0           2936
# Overall_Views                      0           2601
# Sales                              0           3030

# %%
df.describe().T
# Out:
#                         count           mean           std          min  \
# Paid_Views             3051.0   15093.941658  3.078588e+04      1.00000
# Organic_Views          3051.0   13355.673222  2.407940e+04      1.00000
# Google_Impressions     3051.0  886173.830875  1.355076e+06      7.00000
# Email_Impressions      3051.0  760509.377761  6.260141e+05  40894.44732
# Facebook_Impressions   3051.0  269126.887906  4.665117e+05     29.00000
# Affiliate_Impressions  3051.0   22910.902655  2.161764e+04    910.00000
# Overall_Views          3051.0   27980.914127  5.205498e+04      2.00000
# Sales                  3051.0  185901.396591  2.322079e+05  15436.00000
#
#                                25%         50%           75%           max
# Paid_Views                537.0000    2699.000  1.735800e+04  5.181900e+05
# Organic_Views             712.5000    4110.000  1.623050e+04  2.704530e+05
# Google_Impressions     169828.0000  490531.000  1.022622e+06  1.715044e+07
# ...

# %%
plt.figure(figsize=(24,6))
sns.lineplot(data=df,y="Sales",x="Calendar_Week")
plt.show()
